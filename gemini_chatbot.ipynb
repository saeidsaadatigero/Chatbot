# %% [markdown]
# <a href="https://colab.research.google.com/github/saeidsaadatigero/Chatbot/blob/main/gemini_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # gemini chatbot

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai

# تنظیم کلید API
GEMINI_API_KEY = "AIzaSyAlQsFAZ4TnQEecPAoTSDWnfoWRY7NSpFU"  # کلید API خود را اینجا قرار دهید
genai.configure(api_key=GEMINI_API_KEY)

# %% [markdown]
# sk-349860bd3c914e8fad272ba83b602196[link text](https://)

# %%
# ایجاد مدل Gemini
model = genai.GenerativeModel('gemini-1.5-flash')

# شروع چت
chat = model.start_chat(history=[])

# %%
print("چت‌بات Gemini راه‌اندازی شد! برای خروج از چت، 'خروج' را تایپ کنید.")

while True:
    # دریافت ورودی از کاربر
    user_input = input("شما: ")

    # اگر کاربر بخواهد از چت خارج شود
    if user_input.lower() in ["خروج", "exit", "quit"]:
        print("چت‌بات: خدانگهدار! 😊")
        break

    # ارسال پیام به مدل و دریافت پاسخ
    response = chat.send_message(user_input)

    # نمایش پاسخ چت‌بات
    print(f"چت‌بات: {response.text}")
# Out:
# چت‌بات Gemini راه‌اندازی شد! برای خروج از چت، 'خروج' را تایپ کنید.
# شما: سلام
# چت‌بات: سلام علیکم!  چیزی هست که بتونم کمکتون کنم؟
#
# شما: خوبی
# چت‌بات: ممنون، خوبم.  شما چطور هستید؟
#
# شما: یک کد پایتون برای محاسبه واریانس بنویس
# چت‌بات: چند روش برای محاسبه واریانس در پایتون وجود دارد. در اینجا چند مثال ارائه می‌دهم:
#
# **روش اول: استفاده از کتابخانه NumPy**
#
# این روش ساده‌ترین و کارآمدترین روش است، به خصوص برای مجموعه داده‌های بزرگ:
#
# ```python
# import numpy as np
#
# data = [1, 2, 3, 4, 5]  # داده‌های شما
#
# variance = np.var(data)
# print(f"واریانس: {variance}")
#
# #برای محاسبه واریانس جامعه آماری (population variance) از np.var(data, ddof=0) استفاده کنید.
# # ddof = 0 برای واریانس جامعه آماری و ddof = 1 برای واریانس نمونه آماری.
# ```
#
# **روش دوم: محاسبه دستی (بدون استفاده از NumPy)**
#
# این روش برای درک بهتر فرمول واریانس مفید است:
#
# ```python
# data = [1, 2, 3, 4, 5]
#
# n = len(data)
# mean = sum(data) / n
#
# squared_diffs = [(x - mean) ** 2 for x in data]
# variance = sum(squared_diffs) / (n -1) # واریانس نمونه
# #variance = sum(squared_diffs) / n # واریانس جامعه
#
# print(f"واریانس: {variance}")
# ```
#
# توجه کنید که در روش دستی، تفاوت بین محاسبه واریانس نمونه و واریانس جامعه آماری وجود دارد. در کد بالا،  `n - 1`  برای محاسبه واریانس نمونه (sample variance) استفاده شده است. اگر بخواهید واریانس جامعه (population variance) را محاسبه کنید، باید از `n` استفاده کنید.  `ddof=0` در NumPy به همین معنی است.
#
# **روش سوم: استفاده از کتابخانه Statistics**
#
# این روش هم ساده است و مستقیما واریانس را محاسبه می‌کند:
#
# ```python
# import statistics
#
# data = [1, 2, 3, 4, 5]
# variance = statistics.variance(data)  # واریانس نمونه
# print(f"واریانس: {variance}")
#
# # برای واریانس جامعه باید از این روش استفاده کرد :
# #variance = statistics.pvariance(data) #واریانس جامعه
# ```
#
# به طور کلی، استفاده از `NumPy` برای محاسبات آماری در پایتون به دلیل سرعت و کارایی بالایش توصیه می‌شود، مخصوصا برای داده‌های بزرگ.  اگر به درک مفهوم واریانس علاقه‌مند هستید، روش دستی می‌تواند مفید باشد. و اگر  سادگی و  خوانایی کد برایتان مهم‌تر است، از کتابخانه `statistics` استفاده کنید.  فقط به یاد داشته باشید که تفاوت بین واریانس نمونه و واریانس جامعه را در نظر بگیرید.

# %% [markdown]
# Voice Chatbot
